# %%
pip install pdfminer.six

# %%
import pdfminer #At the starting I used pdfminer to extract csv out of PDF file(college_cutoffs.pdf)

# %%
import csv
import os
def export_as_csv(pdf_path, csv_path):
    filename = os.path.splitext(os.path.basename(pdf_path))[0]
    counter = 1
    text = extract_text_from_pdf(pdf_path)
    with open(csv_path, 'w') as csv_file:
        writer = csv.writer(csv_file)
        words = text.split()
        writer.writerow(words)
if __name__ == '__main__':
    pdf_path = 'college_cutoffs.pdf'
    csv_path = 'cutoffs.csv'
    export_as_csv(pdf_path, csv_path)

# %%
#Converted PDF to CSV using ZAMZAR # The inbuilt PDF miner could not differentiate between various categories (GOPENS etc.)

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = pd.read_csv("college_cutoffs.csv")

# %%
df = pd.DataFrame(data)

# %%
df = df[~df[:].isin(['Government of Maharashtra'])]

# %%
df# NOW DELETING UNWANTED DATA # DATA CLEANING #DELETING ROWS CONTAINING UNWANTED DATA
# Out:
#       1002 - Government College of Engineering, Amravati  \
# 0                          100219110 - Civil Engineering
# 1                                                Status:
# 2                                            State Level
# 3                                                    NaN
# 4                                                  Stage
# ...                                                  ...
# 41318                                                  I
# 41319                                                NaN
# 41320  Legends: Starting character G-General, L-Ladie...
# 41321  . Maharashtra State Seats - Cut Off Indicates ...
# 41322                                                NaN
#
#                   Unnamed: 1 Unnamed: 2  \
# 0                        NaN        NaN
# 1      Government Autonomous        NaN
# 2                        NaN        NaN
# 3                     GOPENS       GSCS
# 4                        NaN        NaN
# ...

# %%
for col_name in df.columns: 
    df=df[~df[col_name].isin(["State Common Entrance Test Cell"])]

# %%
df
# Out:
#       1002 - Government College of Engineering, Amravati  \
# 0                          100219110 - Civil Engineering
# 1                                                Status:
# 2                                            State Level
# 3                                                    NaN
# 4                                                  Stage
# ...                                                  ...
# 41318                                                  I
# 41319                                                NaN
# 41320  Legends: Starting character G-General, L-Ladie...
# 41321  . Maharashtra State Seats - Cut Off Indicates ...
# 41322                                                NaN
#
#                   Unnamed: 1 Unnamed: 2  \
# 0                        NaN        NaN
# 1      Government Autonomous        NaN
# 2                        NaN        NaN
# 3                     GOPENS       GSCS
# 4                        NaN        NaN
# ...

# %%
my_list=["State Common Entrance Test Cell"]
for col_name in df.columns:
    print(col_name)
    #df[~df.col_name.str.contains("State Common Entrance Test Cell", na=False)]
# Out:
# 1002 - Government College of Engineering, Amravati
# Unnamed: 1
# Unnamed: 2
# Unnamed: 3
# Unnamed: 4
# Unnamed: 5
# Unnamed: 6
# Unnamed: 7
# Unnamed: 8
# Unnamed: 9
# Unnamed: 10
# Unnamed: 11
# Unnamed: 12
# Unnamed: 13
# Unnamed: 14
# Unnamed: 15
# Unnamed: 16
# Unnamed: 17
# Unnamed: 18
# Unnamed: 19
# Unnamed: 20
# Unnamed: 21
# Unnamed: 22

# %%
df[[~df.iloc[i,:].str.contains("State Common Entrance Test Cell", na=False).any()  for i in range(0,len(df))]]
# Out:
#       1002 - Government College of Engineering, Amravati  \
# 0                          100219110 - Civil Engineering
# 1                                                Status:
# 2                                            State Level
# 3                                                    NaN
# 4                                                  Stage
# ...                                                  ...
# 41318                                                  I
# 41319                                                NaN
# 41320  Legends: Starting character G-General, L-Ladie...
# 41321  . Maharashtra State Seats - Cut Off Indicates ...
# 41322                                                NaN
#
#                   Unnamed: 1 Unnamed: 2  \
# 0                        NaN        NaN
# 1      Government Autonomous        NaN
# 2                        NaN        NaN
# 3                     GOPENS       GSCS
# 4                        NaN        NaN
# ...

# %%
len(df)
# Out:
# 41323

# %%
df[[~df.iloc[i,:].str.contains("Government of Maharashtra", na=False).any()  for i in range(0,len(df))]]
# Out:
#       1002 - Government College of Engineering, Amravati  \
# 0                          100219110 - Civil Engineering
# 1                                                Status:
# 2                                            State Level
# 3                                                    NaN
# 4                                                  Stage
# ...                                                  ...
# 41318                                                  I
# 41319                                                NaN
# 41320  Legends: Starting character G-General, L-Ladie...
# 41321  . Maharashtra State Seats - Cut Off Indicates ...
# 41322                                                NaN
#
#                   Unnamed: 1 Unnamed: 2  \
# 0                        NaN        NaN
# 1      Government Autonomous        NaN
# 2                        NaN        NaN
# 3                     GOPENS       GSCS
# 4                        NaN        NaN
# ...

# %%
df[[~df.iloc[i,:].str.contains("Government Autonomous", na=False).any()  for i in range(0,len(df))]]
# Out:
#       1002 - Government College of Engineering, Amravati    Unnamed: 1  \
# 0                          100219110 - Civil Engineering           NaN
# 2                                            State Level           NaN
# 3                                                    NaN        GOPENS
# 4                                                  Stage           NaN
# 5                                                      I          9698
# ...                                                  ...           ...
# 41318                                                  I         69650
# 41319                                                NaN  (24.0098347)
# 41320  Legends: Starting character G-General, L-Ladie...           NaN
# 41321  . Maharashtra State Seats - Cut Off Indicates ...           NaN
# 41322                                                NaN           NaN
#
#       Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# ...

# %%
df =df[[~df.iloc[i,:].str.contains("Government of Maharashtra", na=False).any()  for i in range(0,len(df))]]

# %%
df
# Out:
#       1002 - Government College of Engineering, Amravati  \
# 0                          100219110 - Civil Engineering
# 1                                                Status:
# 2                                            State Level
# 3                                                    NaN
# 4                                                  Stage
# ...                                                  ...
# 41318                                                  I
# 41319                                                NaN
# 41320  Legends: Starting character G-General, L-Ladie...
# 41321  . Maharashtra State Seats - Cut Off Indicates ...
# 41322                                                NaN
#
#                   Unnamed: 1 Unnamed: 2  \
# 0                        NaN        NaN
# 1      Government Autonomous        NaN
# 2                        NaN        NaN
# 3                     GOPENS       GSCS
# 4                        NaN        NaN
# ...

# %%
df =df[[~df.iloc[i,:].str.contains("State Level", na=False).any()  for i in range(0,len(df))]]

# %%
df
# Out:
#       1002 - Government College of Engineering, Amravati  \
# 0                          100219110 - Civil Engineering
# 1                                                Status:
# 3                                                    NaN
# 4                                                  Stage
# 5                                                      I
# ...                                                  ...
# 41317                                              Stage
# 41318                                                  I
# 41319                                                NaN
# 41321  . Maharashtra State Seats - Cut Off Indicates ...
# 41322                                                NaN
#
#                   Unnamed: 1 Unnamed: 2  \
# 0                        NaN        NaN
# 1      Government Autonomous        NaN
# 3                     GOPENS       GSCS
# 4                        NaN        NaN
# 5                       9698      16599
# ...

# %%
df =df[[~df.iloc[i,:].str.contains("Cut Off List of Maharashtra State Candidature Candidates of", na=False).any()  for i in range(0,len(df))]]

# %%
df
# Out:
#       1002 - Government College of Engineering, Amravati  \
# 0                          100219110 - Civil Engineering
# 1                                                Status:
# 3                                                    NaN
# 4                                                  Stage
# 5                                                      I
# ...                                                  ...
# 41317                                              Stage
# 41318                                                  I
# 41319                                                NaN
# 41321  . Maharashtra State Seats - Cut Off Indicates ...
# 41322                                                NaN
#
#                   Unnamed: 1 Unnamed: 2  \
# 0                        NaN        NaN
# 1      Government Autonomous        NaN
# 3                     GOPENS       GSCS
# 4                        NaN        NaN
# 5                       9698      16599
# ...

# %%
df =df[[~df.iloc[i,:].str.contains("Stage", na=False).any()  for i in range(0,len(df))]]

# %%
df
# Out:
#       1002 - Government College of Engineering, Amravati  \
# 0                          100219110 - Civil Engineering
# 1                                                Status:
# 3                                                    NaN
# 5                                                      I
# 6                                                    NaN
# ...                                                  ...
# 41316                                                NaN
# 41318                                                  I
# 41319                                                NaN
# 41321  . Maharashtra State Seats - Cut Off Indicates ...
# 41322                                                NaN
#
#                   Unnamed: 1    Unnamed: 2  \
# 0                        NaN           NaN
# 1      Government Autonomous           NaN
# 3                     GOPENS          GSCS
# 5                       9698         16599
# 6               (95.4813409)  (91.9454241)
# ...

# %%
df =df[[~df.iloc[i,:].str.contains("Legends: Starting character G-General", na=False).any()  for i in range(0,len(df))]]

# %%
df
# Out:
#       1002 - Government College of Engineering, Amravati  \
# 0                          100219110 - Civil Engineering
# 1                                                Status:
# 3                                                    NaN
# 5                                                      I
# 6                                                    NaN
# ...                                                  ...
# 41316                                                NaN
# 41318                                                  I
# 41319                                                NaN
# 41321  . Maharashtra State Seats - Cut Off Indicates ...
# 41322                                                NaN
#
#                   Unnamed: 1    Unnamed: 2  \
# 0                        NaN           NaN
# 1      Government Autonomous           NaN
# 3                     GOPENS          GSCS
# 5                       9698         16599
# 6               (95.4813409)  (91.9454241)
# ...

# %%
df =df[[~df.iloc[i,:].str.contains("Maharashtra State Seats", na=False).any()  for i in range(0,len(df))]]

# %%
df
# Out:
#       1002 - Government College of Engineering, Amravati  \
# 0                          100219110 - Civil Engineering
# 1                                                Status:
# 3                                                    NaN
# 5                                                      I
# 6                                                    NaN
# ...                                                  ...
# 41315  Home University Seats Allotted to Home Univers...
# 41316                                                NaN
# 41318                                                  I
# 41319                                                NaN
# 41322                                                NaN
#
#                   Unnamed: 1    Unnamed: 2  \
# 0                        NaN           NaN
# 1      Government Autonomous           NaN
# 3                     GOPENS          GSCS
# 5                       9698         16599
# 6               (95.4813409)  (91.9454241)
# ...

# %%
df =df[[~df.iloc[i,:].str.contains("Home University Seats Allotted to Home", na=False).any()  for i in range(0,len(df))]]

# %%
df
# Out:
#       1002 - Government College of Engineering, Amravati  \
# 0                          100219110 - Civil Engineering
# 1                                                Status:
# 3                                                    NaN
# 5                                                      I
# 6                                                    NaN
# ...                                                  ...
# 41314                                            Status:
# 41316                                                NaN
# 41318                                                  I
# 41319                                                NaN
# 41322                                                NaN
#
#                                               Unnamed: 1    Unnamed: 2  \
# 0                                                    NaN           NaN
# 1                                  Government Autonomous           NaN
# ...

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
df =df[[~df.iloc[i,:].str.contains("State Common Entrance", na=False).any()  for i in range(0,len(df))]]

# %%
df =df[[~df.iloc[i,:].str.contains("Year 2019", na=False).any()  for i in range(0,len(df))]]

# %%
df =df[[~df.iloc[i,:].str.contains("Home University Seats Allotted to Other Than", na=False).any()  for i in range(0,len(df))]]

# %%
df =df[[~df.iloc[i,:].str.contains("Other Than Home University Seats Allotted", na=False).any()  for i in range(0,len(df))]]

# %%
newdf =df.reset_index(drop=True) # Resetting Row indexes after successful cleaning

# %%
newdf # newdf has only 23115 rows , before there were 40k+ rows
# Out:
#       1002 - Government College of Engineering, Amravati  \
# 0                          100219110 - Civil Engineering
# 1                                                Status:
# 2                                                    NaN
# 3                                                      I
# 4                                                    NaN
# ...                                                  ...
# 23110                                            Status:
# 23111                                                NaN
# 23112                                                  I
# 23113                                                NaN
# 23114                                                NaN
#
#                                               Unnamed: 1    Unnamed: 2  \
# 0                                                    NaN           NaN
# 1                                  Government Autonomous           NaN
# ...

# %%
asdf =newdf[[newdf.iloc[i,:].str.contains("Home University : Savitribai Phule Pune University", na=False).any()  for i in range(0,len(newdf))]]
#fetching indexes of Phule pune

# %%
arr = list(asdf.index)

# %%
arr
# Out:
# [11604,
#  11625,
#  11641,
#  11657,
#  11673,
#  11689,
#  11709,
#  11730,
#  11750,
#  11766,
#  11781,
#  11797,
#  11817,
#  11830,
#  11848,
#  11867,
#  11880,
#  11895,
#  11920,
#  11938,
#  11954,
#  11974,
#  11995,
#  12015,
#  12040,
#  12063,
#  12084,
#  12100,
#  12116,
#  12136,
#  12152,
#  12171,
#  12187,
#  12203,
#  12223,
#  12236,
#  12246,
#  12263,
#  12270,
#  12277,
#  12293,
#  12312,
#  12328,
#  12344,
#  12357,
#  12373,
#  12393,
#  12413,
#  12429,
#  12445,
#  12466,
#  12485,
#  12498,
#  12578,
#  12585,
#  12590,
#  12595,
#  12602,
#  12609,
#  12618,
#  12639,
#  12655,
#  12675,
#  12691,
#  12713,
#  12729,
#  12745,
#  12764,
#  12783,
#  12799,
#  12810,
#  12823,
#  13156,
#  13167,
#  13180,
#  13196,
#  13214,
#  13222,
#  13235,
#  13243,
#  13253,
#  13269,
#  13285,
#  13301,
#  13314,
#  13330,
#  13350,
#  13363,
#  13377,
#  13387,
#  13410,
#  13426,
#  13442,
#  13455,
#  13473,
#  13490,
#  13497,
#  13505,
#  13518,
#  13533,
# ...

# %%
clg_name_list=[]
GOPENS_rank_list=[]
GOPENH_rank_list=[]
for idx_num in arr:
    if "Civil" in newdf.iloc[idx_num-1,0]:
        GOPENH_rank_list.append(newdf.iloc[idx_num+2,1])
        clg_name_list.append(newdf.iloc[idx_num-2,0])
        if "GOPENH" in newdf.iloc[idx_num+1,1] or "GOPENS" in newdf.iloc[idx_num+1,1] :
            GOPENS_rank_list.append(newdf.iloc[idx_num+2,1])

# %%
t
# Out:
# 79

# %%
newdf.iloc[11919,0]
# Out:
# '512137210 - Electronics and Telecommunication Engg'

# %%
clg_name_list
# Out:
# ["5108 - Nashik District Maratha Vidya Prasarak Samaj's Karmaveer Adv.Babaurao Ganpatrao Thakare College of Engineering, Nashik",
#  '5109 - Sandip Foundation, Sandip Institute of Technology and Research Centre, Mahiravani, Nashik',
#  '5121 - K. K. Wagh Institute of Engineering Education and Research, Nashik',
#  '5121 - K. K. Wagh Institute of Engineering Education and Research, Nashik',
#  "5124 - Jagadamba Education Soc. Nashik's S.N.D. College of Engineering & Reserch, Babulgaon",
#  '5130 - Brahma Valley College of Engineering & Research, Trimbakeshwar, Nashik',
#  '5139 - Pravara Rural College of Engineering, Loni, Pravaranagar, Ahmednagar.',
#  "5151 - MET Bhujbal Knowledge City MET League's Engineering College, Adgaon, Nashik.",
#  "5160 - Sanjivani Rural Education Society's Sanjivani College of Engineering, Kopargaon",
#  '5161 - Dr. Vithalrao Vikhe Patil College of Engineering, Ahmednagar',
# ...

# %%
GOPENS_rank_list
# Out:
# ['38617',
#  '50417',
#  '22937',
#  '32662',
#  '53420',
#  '62679',
#  '37793',
#  '39672',
#  '37829',
#  '36668',
#  '34835',
#  '51433',
#  '84289',
#  '80859',
#  '59772',
#  '52670',
#  '32066',
#  '76658',
#  '86676',
#  '65050',
#  '46250',
#  '72194',
#  '43272',
#  '76835',
#  '86342',
#  '64014',
#  '12456',
#  '1255',
#  '86350',
#  '86522',
#  '32932',
#  '39934',
#  '16173',
#  '77715',
#  '48052',
#  '54833',
#  '85727',
#  '12971',
#  '86331',
#  '32805',
#  '50805',
#  '75089',
#  '85995',
#  '83189',
#  '86733',
#  '69340',
#  '45456',
#  '40070',
#  '48387',
#  '70739',
#  '28635',
#  '51428',
#  '14178',
#  '77452',
#  '70199',
#  '87078',
#  '80753',
#  '78636',
#  '23543',
#  '86104',
#  '80689',
#  '77441',
#  '85375',
#  '86552',
#  '53775',
#  '86534',
#  '58410',
#  '86681',
#  '68434',
#  '83588',
#  '86401',
#  '82394',
#  '84687',
#  '81692',
#  '59535',
#  '46359',
#  '41752',
#  '84073']

# %%
len(clg_name_list)
# Out:
# 79

# %%
len(GOPENH_rank_list)
# Out:
# 79

# %%
testdf = pd.DataFrame()

# %%
testdf['CollegeName']  = clg_name_list

# %%
GOPENH_rank_list[28]='01255'

# %%
testdf['GOPENH/GOPENS']  = GOPENH_rank_list

# %%
testdf
# Out:
#                                           CollegeName GOPENH/GOPENS
# 0   5108 - Nashik District Maratha Vidya Prasarak ...         38617
# 1   5109 - Sandip Foundation, Sandip Institute of ...         50417
# 2   5121 - K. K. Wagh Institute of Engineering Edu...         22937
# 3   5121 - K. K. Wagh Institute of Engineering Edu...         32662
# 4   5124 - Jagadamba Education Soc. Nashik's S.N.D...         53420
# 5   5130 - Brahma Valley College of Engineering & ...         62679
# 6   5139 - Pravara Rural College of Engineering, L...         37793
# 7   5151 - MET Bhujbal Knowledge City MET League's...         39672
# 8   5160 - Sanjivani Rural Education Society's San...         37829
# 9   5161 - Dr. Vithalrao Vikhe Patil College of En...         36668
# 10  5162 - Amrutvahini Sheti & Shikshan Vikas Sans...         34835
# 11  5173 - SNJB's Late Sau. Kantabai Bhavarlalji J...         51433
# 12  5176 - G. H. Raisoni College of Engineering an...         84289
# ...

# %%
testdf.sort_values(by=['GOPENH/GOPENS'],inplace=True)

# %%
testdf
# Out:
#                                           CollegeName GOPENH/GOPENS
# 28                6006 - College of Engineering, Pune         01255
# 27  6004 - Government College of Engineering & Res...         12456
# 38  6175 - Pimpri Chinchwad Education Trust, Pimpr...         12971
# 53  6289 - B.R.A.C.T's Vishwakarma Institute of In...         14178
# 33     6146 - MIT Academy of Engineering,Alandi, Pune         16173
# 2   5121 - K. K. Wagh Institute of Engineering Edu...         22937
# 59                                       6325 - Alard         23543
# 51  6278 - All India Shri Shivaji Memorial Society...         28635
# 16  5184 - Amruta Vaishnavi Education & Welfare Tr...         32066
# 3   5121 - K. K. Wagh Institute of Engineering Edu...         32662
# 40  6177 - Sinhgad College of Engineering, Vadgaon...         32805
# 31  6141 - Jaywant Shikshan Prasarak Mandal's,Raja...         32932
# 10  5162 - Amrutvahini Sheti & Shikshan Vikas Sans...         34835
# ...

# %%
# Picking top 10 colleges from resultant DataFrame:

# %%
testdf.head(10)
# Out:
#                                           CollegeName GOPENH/GOPENS
# 28                6006 - College of Engineering, Pune         01255
# 27  6004 - Government College of Engineering & Res...         12456
# 38  6175 - Pimpri Chinchwad Education Trust, Pimpr...         12971
# 53  6289 - B.R.A.C.T's Vishwakarma Institute of In...         14178
# 33     6146 - MIT Academy of Engineering,Alandi, Pune         16173
# 2   5121 - K. K. Wagh Institute of Engineering Edu...         22937
# 59                                       6325 - Alard         23543
# 51  6278 - All India Shri Shivaji Memorial Society...         28635
# 16  5184 - Amruta Vaishnavi Education & Welfare Tr...         32066
# 3   5121 - K. K. Wagh Institute of Engineering Edu...         32662

# %%
# Second part of the problem where we have to consider GOPENS, GSCS, GSTS,etc

# %%
# We will search for GSCS GSTS etc for the same way I did for GOPENS/H 
# We will append those lists into the resultant dataframe
# Then we will sort the data frame using multiple columns

# %%
# df.sort_values(by=['First Column','Second Column',...], inplace=True)
